# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

# Generate some 3D vector data
a = np.zeros((2,1))
gs = gridspec.GridSpec(1, 1, width_ratios=[1.5]) 
ax1 = plt.subplot(gs[0],projection='3d');
C = np.array([[-1.68, 1.48], [2.46, 1.789], [-1.6, 2.8745]])

# Create a 3D plot
fig = plt.figure()
#ax1 = fig.add_subplot(111, projection='3d')

# Plot the vector field
ax1.quiver(a, a, a, C[0,:], C[1,:], C[2,:], color='r')

# Set the plot limits
#ax.set_xlim([-1, 1])
#ax.set_ylim([-1, 1])
#ax.set_zlim([-1, 1])

# Show the plot
plt.show()
